# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dat=pd.read_csv(r"D:\Juciey.csv")
dat.head()
# Out:
#   Customer_id    Customer_Name Months-of_purchasing  Quantity_(ML)  \
# 0      JH-120      Alok Sharma                April           2000
# 1      JH-112     Apurva Singh                  May           2000
# 2      JH-111        Harsh Raj                  May           1000
# 3      JH-115  Rahul Chaudhary                 June           1000
# 4      JH-121        Priya Roy                 June           3000
#
#    Product_Rating
# 0               4
# 1               5
# 2               3
# 3               4
# 4               3

# %%
dat.tail()
# Out:
#    Customer_id   Customer_Name Months-of_purchasing  Quantity_(ML)  \
# 24      JH-133        Ms Dhoni                 July           1500
# 25      JH-136    Virat Sharma                 July           1500
# 26      JH-138   Anushka Kholi                April           1200
# 27      JH-135  Pankaj Pachori                  May           1500
# 28      JH-137   Mohammad khan                 July           1500
#
#     Product_Rating
# 24               3
# 25               3
# 26               4
# 27               5
# 28               4

# %%
dat['Months-of_purchasing'].value_counts()
# Out:
# May      9
# June     8
# July     5
# April    4
# March    3
# Name: Months-of_purchasing, dtype: int64

# %%
dat.sort_values(by='Product_Rating')
# Out:
#    Customer_id      Customer_Name Months-of_purchasing  Quantity_(ML)  \
# 12      JH-127          Divya Roy                 June           1200
# 2       JH-111          Harsh Raj                  May           1000
# 25      JH-136       Virat Sharma                 July           1500
# 4       JH-121          Priya Roy                 June           3000
# 24      JH-133           Ms Dhoni                 July           1500
# 23      JH-134   Deepak Prajapati                March           1200
# 7       JH-118       Yatendra Lal                April           1500
# 8       JH-119  Priyanka Khaushik                March           2000
# 19      JH-132          Anu Dixit                 June           1000
# 13      JH-126         Allu Arjun                  May           1500
# 17      JH-129       Tanu Agrawal                 July           1500
# 16      JH-117        Krish Gupta                 June           1200
# ...

# %%
import seaborn as sns

# %%
dat.shape
# Out:
# (29, 5)

# %%
sns.lineplot(x="Months-of_purchasing",y="Quantity_(ML)",data=dat)
plt.show()

# %%
sns.lineplot(x="Months-of_purchasing",y="Quantity_(ML)",data=dat,hue="Product_Rating")
plt.show()

# %%
sns.lineplot(x="Months-of_purchasing",y="Quantity_(ML)",data=dat,hue="Product_Rating",style="Product_Rating")
plt.show()

# %%
sns.lineplot(x="Months-of_purchasing",y="Quantity_(ML)",data=dat,hue="Product_Rating",markers=True,style="Product_Rating")
plt.show()

# %%
sns.set(style="whitegrid")
sns.barplot(x="Months-of_purchasing",y="Product_Rating",data=dat)
plt.show()

# %%
sns.barplot(x="Months-of_purchasing",y="Product_Rating",data=dat,hue="Quantity_(ML)")
plt.show()
